# %%
path = '/content/SpotifyAudioFeaturesApril2019.csv'

# %%
import pandas as pd

df = pd.read_csv(path)

# %%
print(df.shape)
df.head()
# Out:
# (130663, 17)
#   artist_name                track_id  ... valence  popularity
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O  ...   0.118          15
# 1          YG  1tHDG53xJNGsItRA3vfVgs  ...   0.371           0
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy  ...   0.382          56
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91  ...   0.641           0
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS  ...   0.928           0
#
# [5 rows x 17 columns]

# %%
df.tail()
# Out:
#                   artist_name                track_id  ... valence  popularity
# 130658            Calum Scott  0cvfSKcm9VeduwyYPrxtLx  ...  0.2890          57
# 130659           Saint Claire  43MP9F7UzvfilSrw2SqZGJ  ...  0.3460          60
# 130660              Mike Stud  4TWlUuFk81NGUNKwndyS5Q  ...  0.5460          47
# 130661               D Savage  5iGBXzOoRo4sBTy8wdzMyK  ...  0.0755          50
# 130662  Banda Los Sebastianes  7LNtyuekYHiZ99UxkrfCQR  ...  0.9760          55
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 17 columns):
# artist_name         130663 non-null object
# track_id            130663 non-null object
# track_name          130663 non-null object
# acousticness        130663 non-null float64
# danceability        130663 non-null float64
# duration_ms         130663 non-null int64
# energy              130663 non-null float64
# instrumentalness    130663 non-null float64
# key                 130663 non-null int64
# liveness            130663 non-null float64
# loudness            130663 non-null float64
# mode                130663 non-null int64
# speechiness         130663 non-null float64
# tempo               130663 non-null float64
# time_signature      130663 non-null int64
# valence             130663 non-null float64
# popularity          130663 non-null int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 16.9+ MB

# %%
df.describe()
# Out:
#         acousticness   danceability  ...        valence     popularity
# count  130663.000000  130663.000000  ...  130663.000000  130663.000000
# mean        0.342500       0.581468  ...       0.439630      24.208988
# std         0.345641       0.190077  ...       0.259079      19.713191
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.031600       0.459000  ...       0.224000       7.000000
# 50%         0.203000       0.605000  ...       0.420000      22.000000
# 75%         0.636000       0.727000  ...       0.638000      38.000000
# max         0.996000       0.996000  ...       1.000000     100.000000
#
# [8 rows x 14 columns]

# %%
len(df['track_id'])
# Out:
# 130663

# %%
df['track_id'].nunique()
# Out:
# 130326

# %% [markdown]
# ### No duplicates!

# %%
(df['track_id'].value_counts() > 1).value_counts()
# Out:
# False    129998
# True        328
# Name: track_id, dtype: int64

# %%
df1 = df.drop_duplicates('track_id', keep='first')

# %%
(df1['track_id'].value_counts() > 1).value_counts()
# Out:
# False    130326
# Name: track_id, dtype: int64

# %% [markdown]
# ### Export new csv

# %%
df1.to_csv('Dataset.csv')
