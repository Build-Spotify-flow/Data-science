# %%
path = '/content/SpotifyAudioFeaturesApril2019.csv'
path1 = '/content/SpotifyAudioFeaturesNov2018.csv'

# %%
import pandas as pd

df = pd.read_csv(path)
df1 = pd.read_csv(path1)

# %%
print(df.shape)
df.head()
# Out:
# (130663, 17)
#   artist_name                track_id  ... valence  popularity
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O  ...   0.118          15
# 1          YG  1tHDG53xJNGsItRA3vfVgs  ...   0.371           0
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy  ...   0.382          56
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91  ...   0.641           0
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS  ...   0.928           0
#
# [5 rows x 17 columns]

# %%
print(df1.shape)
df1.head()
# Out:
# (116372, 17)
#   artist_name                track_id  ... valence  popularity
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O  ...   0.118          44
# 1          YG  1tHDG53xJNGsItRA3vfVgs  ...   0.371          10
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy  ...   0.382          63
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91  ...   0.641           9
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS  ...   0.928           8
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130663 entries, 0 to 130662
# Data columns (total 17 columns):
# artist_name         130663 non-null object
# track_id            130663 non-null object
# track_name          130663 non-null object
# acousticness        130663 non-null float64
# danceability        130663 non-null float64
# duration_ms         130663 non-null int64
# energy              130663 non-null float64
# instrumentalness    130663 non-null float64
# key                 130663 non-null int64
# liveness            130663 non-null float64
# loudness            130663 non-null float64
# mode                130663 non-null int64
# speechiness         130663 non-null float64
# tempo               130663 non-null float64
# time_signature      130663 non-null int64
# valence             130663 non-null float64
# popularity          130663 non-null int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 16.9+ MB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116372 entries, 0 to 116371
# Data columns (total 17 columns):
# artist_name         116372 non-null object
# track_id            116372 non-null object
# track_name          116372 non-null object
# acousticness        116372 non-null float64
# danceability        116372 non-null float64
# duration_ms         116372 non-null int64
# energy              116372 non-null float64
# instrumentalness    116372 non-null float64
# key                 116372 non-null int64
# liveness            116372 non-null float64
# loudness            116372 non-null float64
# mode                116372 non-null int64
# speechiness         116372 non-null float64
# tempo               116372 non-null float64
# time_signature      116372 non-null int64
# valence             116372 non-null float64
# popularity          116372 non-null int64
# dtypes: float64(9), int64(5), object(3)
# memory usage: 15.1+ MB

# %%
df.describe()
# Out:
#         acousticness   danceability  ...        valence     popularity
# count  130663.000000  130663.000000  ...  130663.000000  130663.000000
# mean        0.342500       0.581468  ...       0.439630      24.208988
# std         0.345641       0.190077  ...       0.259079      19.713191
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.031600       0.459000  ...       0.224000       7.000000
# 50%         0.203000       0.605000  ...       0.420000      22.000000
# 75%         0.636000       0.727000  ...       0.638000      38.000000
# max         0.996000       0.996000  ...       1.000000     100.000000
#
# [8 rows x 14 columns]

# %%
df1.describe()
# Out:
#         acousticness   danceability  ...        valence     popularity
# count  116372.000000  116372.000000  ...  116372.000000  116372.000000
# mean        0.335472       0.582476  ...       0.438393      24.235082
# std         0.343066       0.189869  ...       0.259566      17.931939
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.029500       0.461000  ...       0.222000      10.000000
# 50%         0.194000       0.606000  ...       0.419000      22.000000
# 75%         0.620000       0.728000  ...       0.637000      35.000000
# max         0.996000       0.996000  ...       1.000000     100.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# ### Combine DFs

# %%
full = pd.concat([df, df1], ignore_index=True)
print(full.shape)
full.head()
# Out:
# (247035, 17)
#   artist_name                track_id  ... valence  popularity
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O  ...   0.118          15
# 1          YG  1tHDG53xJNGsItRA3vfVgs  ...   0.371           0
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy  ...   0.382          56
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91  ...   0.641           0
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS  ...   0.928           0
#
# [5 rows x 17 columns]

# %%
full.tail()
# Out:
#             artist_name                track_id  ... valence  popularity
# 247030  Roma Atmosphere  5R9ukMX7BDIy1WJYsAhBD6  ...   0.037          55
# 247031     Philthy Rich  6LlTJUQPhqvZuvOmgkLGYh  ...   0.613          46
# 247032  Nef The Pharaoh  0B2LhMYcGR9Gmi6BQLdzlO  ...   0.584          47
# 247033   The Ting Tings  0yzA9b21pJgnlLQDirsxAm  ...   0.271          50
# 247034        mingi pak  2ud0K7X5LzmxJP2LEvkHio  ...   0.433          52
#
# [5 rows x 17 columns]

# %%
full.duplicated().value_counts()
# Out:
# False    222144
# True      24891
# dtype: int64

# %% [markdown]
# ### No duplicates!

# %%
full = full.drop_duplicates('track_id', keep='first')

# %%
full.duplicated().value_counts()
# Out:
# False    130989
# dtype: int64

# %%
full.shape
# Out:
# (130989, 17)

# %% [markdown]
# ### Export new csv

# %%
full.to_csv('Dataset.csv', index=False)
